# %% [markdown]
# # Supplementary material

# %%
# Membrane potential dependence on extracellular potassium
# Reproduces classical experimental / constant field model findings
import figure_2or3
figure_2or3.k_vm()

# %%
# Complete fluxes, concentrations, potentials of time-dependent simulations
# Figures 1C, 3A, 4A, 4C, 4D, 5A, 5C, 6A, 6C
import figure_1, fig4, fig5
from plotting import fluxplot

fluxplot(figure_1.f1c())
fluxplot(figure_2or3.f3a())
fluxplot(fig4.f4a()[1])
fluxplot(fig4.f4c()[0])
fluxplot(fig4.f4d())
fluxplot(fig5.f5a()[0])
fluxplot(fig5.f5c())
f6a=fig5.f5a(new=1)
fluxplot(f6a[0])
fluxplot(f6a[1])
f6b=fig4.f4c(new=1)
fluxplot(f6b[0])
fluxplot(f6b[1])
fluxplot(f6b[2])
# Out:
# Figure 1C
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014001605631267964 k 0.12287337072262554 cl 0.005164834122403739 x 0.1549601891739127 vm -0.07258809573569151 cle 0.119 ose 0.297 osi 0.2969999996500977 deltx 6.419939373305847e-25
# w 1.9635183534149513e-12 radius 5.0000292142958414e-05 z -0.85
# ecl -83.84301812126984
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014064750308406704 k 0.12267775556879207 cl 0.003532343988517994 x 0.1567251498782517 vm -0.07454005208389158 cle 0.119 ose 0.297 osi 0.29699999974388586 deltx -2.524354896707238e-28
# w 1.941406186099366e-12 radius 4.9717955796021876e-05 z -0.85
# ecl -93.9961497225862
# Figure 3A
# 3.80729610662e-07
# -83.85251199079462
# 5.163
# 3.5323439885552235
# -93.9961497225862
# Figure 4A
# 0.1115
# k_init: 0.131498
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014001590857927826 k 0.12287254914676243 cl 0.005204502295010624 x 0.1549193837096392 vm -0.07255068740187595 cle 0.119 ose 0.297 osi 0.29699802476247483 deltx -9.93333651854298e-27
# w 5.069721713258281e-13 radius 2.5406633319121488e-05 z -0.85
# ecl -83.63550944795966
# 0.0745
# k_init: 0.128498
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014001638032394915 k 0.12287218435156493 cl 0.005166887271126337 x 0.1549591897712806 vm -0.07258598956458032 cle 0.119 ose 0.297 osi 0.2969998993814486 deltx 1.464125840090198e-27
# w 1.013683879680452e-12 radius 3.592579019965618e-05 z -0.85
# ecl -83.83228812113266
# 0.0375
# k_init: 0.125498
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014001644895332035 k 0.1228728992065759 cl 0.005165023396541561 x 0.15496042357791484 vm -0.07258785634468298 cle 0.119 ose 0.297 osi 0.2969999910731105 deltx -7.068193710780266e-28
# w 1.5205137129788702e-12 radius 4.3999752131992616e-05 z -0.85
# ecl -83.84203246808721
# 0.0005
# k_init: 0.122498
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014001648076340613 k 0.12287337914467461 cl 0.005164821572589905 x 0.15496015141562983 vm -0.07258811935099303 cle 0.119 ose 0.297 osi 0.29700000020930106 deltx -3.534096855390133e-28
# w 2.027355178018313e-12 radius 5.080658209205291e-05 z -0.85
# ecl -83.84308489265673
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014001648791739521 k 0.12287349743522405 cl 0.005164821129328071 x 0.15496003264379857 vm -0.07258813764180369 cle 0.119 ose 0.297 osi 0.2970000000000902 deltx 3.46455653951616e-14
# w 2.1870977638808154e-12 radius 5.2770250721167716e-05 z -0.85
# ecl -83.84308702483436
#
# Figure 4C
# Figure 4D
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014000625047112103 k 0.12270573151243498 cl 0.0030854608268133547 x 0.157208182545398 vm -0.0725565595184879 cle 0.0709999999975 ose 0.296999999997 osi 0.2969999999317373 deltx -4.897248499612041e-27
# w 1.9354410856007342e-12 radius 4.964151616028673e-05 z -0.85
# ecl -83.80903479197723
# 11.25247528883753
# 11.2554863279221
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1
# na 0.014050727165544527 k 0.13121939338865052 cl 0.004857608733395854 x 0.14687228435871483 vm -0.07410710465379503 cle 0.119 ose 0.297 osi 0.2970000136505685 deltx -6.2240494333213655e-25
# w 2.0716446048271188e-12 radius 5.135854197213095e-05 z -0.9560584860981142
# ecl -85.48198693315533
# Figure 5A
# 11.374880258927519
# Figure 5C
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1.5
# anions stopped diffusing at 1339.39999998
# na 0.014068300106164628 k 0.13435720356818862 cl 0.004750823214685574 x 0.1438237372999851 vm -0.0746541554191721 cle 0.119 ose 0.297 osi 0.2970000642064429 deltx 9.049064955080172e-14
# w 2.7447334664820383e-12 radius 5.911601466001371e-05 z -0.9990000159003938
# ecl -86.07604759846005
# 2340
# 11.421888814609588
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1
# na 0.014050727165544527 k 0.13121939338865052 cl 0.004857608733395854 x 0.14687228435871483 vm -0.07410710465379503 cle 0.119 ose 0.297 osi 0.2970000136505685 deltx -6.2240494333213655e-25
# w 2.0716446048271188e-12 radius 5.135854197213095e-05 z -0.9560584860981142
# ecl -85.48198693315533
# Figure 6A
# 11.374880258927519
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1
# na 0.015177046157236971 k 0.13009478541707195 cl 0.0048664923956223734 x 0.14686168318271214 vm -0.074240768042604 cle 0.119 ose 0.297 osi 0.2970000071548776 deltx -5.911029426129668e-25
# w 2.071794146005091e-12 radius 5.136039559081002e-05 z -0.9560787315105351
# ecl -85.43315112365384
# 11.192303790970783
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014001648791739521 k 0.12287349743522405 cl 0.005164821129328071 x 0.15496003264379857 vm -0.07258813764180369 cle 0.119 ose 0.297 osi 0.2970000000000902 deltx 3.46455653951616e-14
# w 2.1870977638808154e-12 radius 5.2770250721167716e-05 z -0.85
# ecl -83.84308702483436
#
# Figure 6C
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014016605270409816 k 0.12535343455811326 cl 0.005069486927074248 x 0.1580074712866179 vm -0.07304994132134171 cle 0.119 ose 0.297 osi 0.3024469980422152 deltx 3.4340907485951775e-14
# w 2.1429877981068472e-12 radius 5.223539804035737e-05 z -0.85
# ecl -84.3409966514777
# 11.291055330137283
# 6.995419196871907
# 1800
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014276378052554928 k 0.12509459813920737 cl 0.005072290534604578 x 0.15800527684991372 vm -0.07307568940194618 cle 0.119 ose 0.297 osi 0.3024485435762131 deltx 3.434442907814654e-14
# w 2.143039848541108e-12 radius 5.22360324020287e-05 z -0.85
# ecl -84.32622042861135
# 11.250517492685375
# 1800

# %%
from plm_singlecomp_withkcc2 import plm
dex=plm(tt=500,graph=1,kccmodel=2)
# Out:
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.013929638829765343 k 0.12314675098458133 cl 0.007556931999478343 x 0.15238266444832543 vm -0.0706258928801462 cle 0.119 ose 0.297 osi 0.29701599134894097 deltx -9.693522803355793e-27
# w 1.996730905005004e-12 radius 5.042139177419839e-05 z -0.85
# ecl -73.67169901447618

# %%
import figure_1
figure_1.f1b(ham=1)
# Out:
# Figure 1B
# k_init: 0.1187157
# osi: 0.2886797
# z_aim: -100 with zflux of -1
# na 0.018322009636175876 k 0.11855896675361699 cl 0.005238900967931575 x 0.15488012758193972 vm -0.07278125453955253 cle 0.119 ose 0.297 osi 0.2970000049412487 deltx 9.744009901289938e-27
# w 1.9645333474433304e-12 radius 5.00132137031384e-05 z -0.85
# ecl -83.46249306007631
# k_init: 0.1327157
# osi: 0.3166797
# z_aim: -100 with zflux of -1
# na 0.01830311617924668 k 0.11857785654509895 cl 0.005238858959419487 x 0.15488017233515983 vm -0.07277759075953587 cle 0.119 ose 0.297 osi 0.2970000040202141 deltx -1.2268364797997176e-26
# w 1.9645327797837393e-12 radius 5.001320647738107e-05 z -0.85
# ecl -83.46270665994888
# k_init: 0.1677157
# osi: 0.3866797
# z_aim: -100 with zflux of -1
# na 0.018280153355405688 k 0.11860089969756309 cl 0.005240256931062419 x 0.15487862156602622 vm -0.07277179354229463 cle 0.119 ose 0.297 osi 0.2969999315281003 deltx -2.716205868856988e-26
# w 1.9645524502634424e-12 radius 5.001345686294613e-05 z -0.85
# ecl -83.45552014158432
# k_init: 0.2077157
# osi: 0.4666797
# z_aim: -100 with zflux of -1
# na 0.018299791099516193 k 0.11858260056527298 cl 0.005263101741535064 x 0.1548533179098642 vm -0.07275470586797929 cle 0.119 ose 0.297 osi 0.29699881093491926 deltx 1.317713256081178e-26
# w 1.9648734660506726e-12 radius 5.0017542896233515e-05 z -0.85
# ecl -83.33840448762714

# %%
import figure_1
ti=figure_1.f1d(time=100000,ham=1)
# Out:
# k_init: 0.002
# osi: 0.292
# z_aim: -100 with zflux of -1
# na 0.1377419971594815 k 0.005301540762270592 cl 0.08120683474745824 x 0.0727496852206341 vm -0.009316195567721348 cle 0.119 ose 0.297 osi 0.2970000579025701 deltx -9.641016221504283e-25
# w 4.18238477001306e-12 radius 7.297381503305626e-05 z -0.85
# ecl -10.212275456311387
# -1.8342205594166094e-11
# k_init: 0.002
# osi: 0.292
# z_aim: -100 with zflux of -1
# na 0.13447482303011812 k 0.007048236768750375 cl 0.062457813038131915 x 0.09301912751114352 vm -0.01574763355732935 cle 0.119 ose 0.297 osi 0.2970000003482305 deltx 1.868022623563356e-27
# w 3.271017301839771e-12 radius 6.453517320202457e-05 z -0.85
# ecl -17.227794467393046
# -3.0680281448085584e-11
# k_init: 0.002
# osi: 0.292
# z_aim: -100 with zflux of -1
# na 0.12853055473627426 k 0.01122562932032264 cl 0.04067218186586811 x 0.11657163407745244 vm -0.02623651311735452 cle 0.119 ose 0.297 osi 0.29699999999991744 deltx 1.059219314658357e-24
# w 2.610130482428398e-12 radius 5.7648255369494954e-05 z -0.85
# ecl -28.691402158101763
# -5.088643925075427e-11
# k_init: 0.002
# osi: 0.292
# z_aim: -100 with zflux of -1
# na 0.12337632105656995 k 0.015528736159910376 cl 0.03017920324638773 x 0.12791573953704546 vm -0.03351345989802458 cle 0.119 ose 0.297 osi 0.2969999999999135 deltx -2.813579324900614e-22
# w 2.378653137689222e-12 radius 5.503267427732629e-05 z -0.85
# ecl -36.66591001364309
# -6.534591122930124e-11
# k_init: 0.002
# osi: 0.292
# z_aim: -100 with zflux of -1
# na 0.1152309402555732 k 0.02293840969021148 cl 0.021110634337940987 x 0.13772001571618453 vm -0.04218924350463305 cle 0.119 ose 0.297 osi 0.2969999999999102 deltx -5.1867920062643615e-24
# w 2.209317025586462e-12 radius 5.303762630278009e-05 z -0.85
# ecl -46.21678741823595
# -8.348538976519314e-11
# k_init: 0.002
# osi: 0.292
# z_aim: -100 with zflux of -1
# na 0.10224635888647549 k 0.035365748293433946 cl 0.01424361956275014 x 0.14514427325724827 vm -0.05165001920298351 cle 0.119 ose 0.297 osi 0.29699999999990784 deltx -6.6855015084394485e-25
# w 2.096308511952436e-12 radius 5.166336124743304e-05 z -0.85
# ecl -56.73221581945178
# -1.0534687505151181e-10
# k_init: 0.00375
# osi: 0.28875
# z_aim: -100 with zflux of -1
# na 0.097640517444605 k 0.039936400135120786 cl 0.01396271728979296 x 0.14543363228254702 vm -0.054617581373456625 cle 0.119 ose 0.297 osi 0.2969732588432119 deltx -1.150600961919159e-25
# w 2.0921376349849124e-12 radius 5.161194018724242e-05 z -0.85
# ecl -57.25017089189112
# -1.6174204374528663e-10
# k_init: 0.00375
# osi: 0.28875
# z_aim: -100 with zflux of -1
# na 0.048216426001080746 k 0.08875769429977971 cl 0.006392456528964669 x 0.15363229537179948 vm -0.07009978961900742 cle 0.119 ose 0.297 osi 0.29699887184131374 deltx 7.522577592187569e-27
# w 1.9804896799507608e-12 radius 5.021591160631453e-05 z -0.85
# ecl -78.14259243539979
# -1.7124869629935444e-10
# k_init: 0.00375
# osi: 0.28875
# z_aim: -100 with zflux of -1
# na 0.01414149420049499 k 0.12273362244416826 cl 0.005166563709602129 x 0.1549583205682646 vm -0.07260037258237532 cle 0.119 ose 0.297 osi 0.29700000092282597 deltx -9.44108731368507e-27
# w 1.963542031013033e-12 radius 5.0000593612830144e-05 z -0.85
# ecl -83.83407315131033
# -2.3285528788058183e-10
# k_init: 0.00375
# osi: 0.28875
# z_aim: -100 with zflux of -1
# na 0.007723460269376187 k 0.12914999115364917 cl 0.0051454026924331545 x 0.15498114588444625 vm -0.0714580595498389 cle 0.119 ose 0.297 osi 0.2969999999999048 deltx -6.6572287335963275e-25
# w 1.963252844427824e-12 radius 4.999691148300358e-05 z -0.85
# ecl -83.94375571023092
# -2.588111345993992e-10
# k_init: 0.00375
# osi: 0.28875
# z_aim: -100 with zflux of -1
# na 0.00569653266811773 k 0.13117999562965224 cl 0.005182900746303246 x 0.15494057095583158 vm -0.07065314397335741 cle 0.119 ose 0.297 osi 0.2969999999999048 deltx -5.909514813191644e-25
# w 1.9637669695765734e-12 radius 5.0003457503552955e-05 z -0.85
# ecl -83.7496986903497
# -2.714733837904038e-10
# k_init: 0.00375
# osi: 0.28875
# z_aim: -100 with zflux of -1
# na 0.004530433313631817 k 0.1323495508240701 cl 0.00522514612504325 x 0.15489486973715963 vm -0.0699820286628734 cle 0.119 ose 0.297 osi 0.2969999999999048 deltx 5.89083458695601e-25
# w 1.9643463725292322e-12 radius 5.001083363693599e-05 z -0.85
# ecl -83.53274848616644
# -2.8088759545654387e-10
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
#
# Figure 1D

# %%
from plm_singlecomp_withkcc2 import plm, default_p, F, nao, qpump
import matplotlib.pyplot as plt
import numpy as np

vel0=[]
vel1=[]
vel2=[]

naspace=range(1,22)

for na in naspace:
    na=na*0.001 
    jp=10**(default_p)/(F)*(na/nao)**3 # cubic pump rate update (dependent on sodium gradient)
    vel0.append(jp)
    jp=(0.014/nao)**2*10**(default_p)/F*na/nao # linear
    vel1.append(jp)
    jp=qpump*(1.62/(1+(0.0067/na)**3)+1.0/(1+(0.0676/na)**3))/F # hamada
    vel2.append(jp)

plt.plot(naspace,vel0,'k')
plt.plot(naspace,vel1,'g')
plt.plot(naspace,vel2,'r')
plt.savefig('naspace.eps')
plt.show()

# %%
from plm_singlecomp_withkcc2 import plm, vmax, kd, gkcc, cle, ke, F, R
import matplotlib.pyplot as plt
import numpy as np

pkcc=gkcc
k=0.118

vel0=[]
vel1=[]
vel2=[]
vel3=[]

clspace=range(1,54)

for cl in clspace:
    cl=cl*0.001 
    externals=cle*ke/k
    fix=np.log(externals/0.056)
    jkcc2=-0.117*np.log(externals/cl)/fix*vmax*cl/(kd+cl)/F #Raimondo -0.117*
    vel1.append(jkcc2)

    jkcc2=51.55*pkcc*(ke*cle-k*cl) #Fraser and Huang 51.55*
    vel2.append(jkcc2)

    jkcc2=0.011125*0.3*(ke*cle-k*cl)/(0.000054*((1+ke*cle/0.000054)*(1+ke/0.009)*(1+cle/0.006)+(1+k*cl/0.000054)*(1+k/0.009)*(1+cl/0.006)))/F
    vel3.append(jkcc2)#Lewin 0.01112*
    
    jkcc2=pkcc*(R*np.log(ke/k)-R*np.log(cl/cle)) #Doyon
    vel0.append(jkcc2)

plt.plot(clspace,vel0,'k')
plt.plot(clspace,vel1,'g')
plt.plot(clspace,vel2,'r')
plt.plot(clspace,vel3,'b')
plt.savefig('clspace.eps')
plt.show()

# %%
# Figure 3A tests (different KCC2s and ATPase)
from plm_singlecomp_withkcc2 import plm
from plotting import minithreefig
import matplotlib.pyplot as plt

dg=plm(tk=120,tt=600,kccmodel=0)
print dg[24][-1]
print dg[14][0]
print dg[17][0]
print dg[17][-1]
print dg[14][-1]

dg=plm(tk=120,tt=600,kccmodel=1)
a1,a2,a3=minithreefig([dg[11][4:-1],dg[14][4:-1],dg[13][4:-1],dg[16][4:-1],dg[10][4:-1],dg[24][4:-1]],'k',yl=[[-100,-70],[1.92e-12,1.98e-12],[0,6e-7]])
plt.savefig('f3araimondo.eps')
plt.show()
print dg[24][-1]
print dg[14][0]
print dg[17][0]
print dg[17][-1]
print dg[14][-1]

dg=plm(tk=120,tt=600,kccmodel=1,hamada=1)
a1,a2,a3=minithreefig([dg[11][4:-1],dg[14][4:-1],dg[13][4:-1],dg[16][4:-1],dg[10][4:-1],dg[24][4:-1]],'k',yl=[[-100,-70],[1.92e-12,1.98e-12],[0,6e-7]])
plt.savefig('f3araimondo+hamada.eps')
plt.show()
print dg[24][-1]
print dg[14][0]
print dg[17][0]
print dg[17][-1]
print dg[14][-1]
# Out:
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014064750308406704 k 0.12267775556879207 cl 0.003532343988517994 x 0.1567251498782517 vm -0.07454005208389158 cle 0.119 ose 0.297 osi 0.29699999974388586 deltx -2.524354896707238e-28
# w 1.941406186099366e-12 radius 4.9717955796021876e-05 z -0.85
# ecl -93.9961497225862
# 3.80729610662e-07
# -83.85251199079462
# 5.163
# 3.5323439885552235
# -93.9961497225862
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014064765963812707 k 0.12267770558401837 cl 0.0035319208310454118 x 0.15672560739342933 vm -0.07454066039275158 cle 0.119 ose 0.297 osi 0.29699999977223235 deltx -2.655621351336014e-26
# w 1.941400518724154e-12 radius 4.971788322735543e-05 z -0.85
# ecl -93.99935143822564
# 3.80729610662e-07
# -83.85251199079462
# 5.163
# 3.531920831078568
# -93.99935143822564
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014477642769265034 k 0.12226572242399682 cl 0.003542665689219837 x 0.15671401740993957 vm -0.07454013985157938 cle 0.119 ose 0.297 osi 0.29700004830800386 deltx 1.2116903504194741e-26
# w 1.9415440974567372e-12 radius 4.971972166785589e-05 z -0.85
# ecl -93.91817175288452
# 3.80729610662e-07
# -83.85251199079462
# 5.163
# 3.5426656816946323
# -93.91817175288452

# %%
from fig4 import f4c
a=f4c(new=1,ham=1,title='f6chamada.eps')
a=f4c(new=1)
# Out:
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014140378150443927 k 0.12273491140596622 cl 0.005166594439669866 x 0.1549581160378854 vm -0.07259994212850894 cle 0.119 ose 0.297 osi 0.29700000003397575 deltx 3.464868381942423e-14
# w 2.187144939394796e-12 radius 5.2770819843023525e-05 z -0.85
# ecl -83.8339127822709
#
# Figure 6C
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.0142390491974249 k 0.12513184138397368 cl 0.005072112592803684 x 0.15800538490952942 vm -0.0730695423734036 cle 0.119 ose 0.297 osi 0.30244838808374147 deltx 3.43438320269749e-14
# w 2.1430346042436775e-12 radius 5.223596848780464e-05 z -0.85
# ecl -84.32715847691425
# 11.257615956553636
# 6.955897923521405
# 1800
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014276378052554928 k 0.12509459813920737 cl 0.005072290534604578 x 0.15800527684991372 vm -0.07307568940194618 cle 0.119 ose 0.297 osi 0.3024485435762131 deltx 3.434442907814654e-14
# w 2.143039848541108e-12 radius 5.22360324020287e-05 z -0.85
# ecl -84.32622042861135
# 11.250517492685375
# 1800
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014001648791739521 k 0.12287349743522405 cl 0.005164821129328071 x 0.15496003264379857 vm -0.07258813764180369 cle 0.119 ose 0.297 osi 0.2970000000000902 deltx 3.46455653951616e-14
# w 2.1870977638808154e-12 radius 5.2770250721167716e-05 z -0.85
# ecl -83.84308702483436
#
# Figure 6C
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014016605270409816 k 0.12535343455811326 cl 0.005069486927074248 x 0.1580074712866179 vm -0.07304994132134171 cle 0.119 ose 0.297 osi 0.3024469980422152 deltx 3.4340907485951775e-14
# w 2.1429877981068472e-12 radius 5.223539804035737e-05 z -0.85
# ecl -84.3409966514777
# 11.291055330137283
# 6.995419196871907
# 1800
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014276378052554928 k 0.12509459813920737 cl 0.005072290534604578 x 0.15800527684991372 vm -0.07307568940194618 cle 0.119 ose 0.297 osi 0.3024485435762131 deltx 3.434442907814654e-14
# w 2.143039848541108e-12 radius 5.22360324020287e-05 z -0.85
# ecl -84.32622042861135
# 11.250517492685375
# 1800

# %%
from fig5 import f5a
b=f5a(ham=1,title='f6ahamada.eps')
# Out:
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1
# na 0.014510265935167388 k 0.13076113648154633 cl 0.0048607321786220984 x 0.14686790200326053 vm -0.07416186983336893 cle 0.119 ose 0.297 osi 0.2970000366100286 deltx -5.678788775632602e-25
# w 2.071706420124839e-12 radius 5.135930820391435e-05 z -0.9560745041440951
# ecl -85.46482714734327
# Figure 6A
# 11.302903674003872
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1
# na 0.015177046157236971 k 0.13009478541707195 cl 0.0048664923956223734 x 0.14686168318271214 vm -0.074240768042604 cle 0.119 ose 0.297 osi 0.2970000071548776 deltx -5.911029426129668e-25
# w 2.071794146005091e-12 radius 5.136039559081002e-05 z -0.9560787315105351
# ecl -85.43315112365384
# 11.192303790970783
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1
# na 0.014050727165544527 k 0.13121939338865052 cl 0.004857608733395854 x 0.14687228435871483 vm -0.07410710465379503 cle 0.119 ose 0.297 osi 0.2970000136505685 deltx -6.2240494333213655e-25
# w 2.0716446048271188e-12 radius 5.135854197213095e-05 z -0.9560584860981142
# ecl -85.48198693315533
# Figure 6A
# 11.374880258927519
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1
# na 0.015177046157236971 k 0.13009478541707195 cl 0.0048664923956223734 x 0.14686168318271214 vm -0.074240768042604 cle 0.119 ose 0.297 osi 0.2970000071548776 deltx -5.911029426129668e-25
# w 2.071794146005091e-12 radius 5.136039559081002e-05 z -0.9560787315105351
# ecl -85.43315112365384
# 11.192303790970783
