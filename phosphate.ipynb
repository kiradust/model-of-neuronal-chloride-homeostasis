# %%
from plm_singlecomp_withkcc2 import plm
from plotting import minithreefig

# %%
dex=plm(tt=1000,ecp=5e-9,xp=200,tpend=600)
# Out:
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.009672184130155562 k 0.127088583799534 cl 0.0037653952747026868 x 0.15647382697840773 vm -0.0885797011224174 cle 0.119 ose 0.297 osi 0.2969999901796347 deltx -3.145346201297218e-26
# w 1.944524406199534e-12 radius 4.9757867414871266e-05 z -0.8499999999999948
# ecl -92.28865225786389

# %%
ax0,ax1,ax2=minithreefig([dex[11][1:-1],dex[14][1:-1],dex[13][1:-1],dex[16][1:-1],dex[12][1:-1],dex[10][1:-1],dex[20][1:-1]],colour='#d95f02',yl=[[-100,-70],[1.9e-12,2.5e-12],[154,157]])
