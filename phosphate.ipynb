# %%
from plm_singlecomp_withkcc2 import plm, R, nao, zp
from plotting import minithreefig
import matplotlib.pyplot as plt
import numpy as np
from fig5 import f5d
from figure_2or3 import delta_gs3
# electroneutral 2Na/H2PO4^2-
# electrogenic 2Na/H2PO4-
# phosphate doubling over time -- intracellular Pi is 5-10 mM

# %%
#dez = f5d()
pi, ena, ek, ecl, exi, ev, nai, ki, cli, xi, vm, w, z = zp(np.linspace(-400,99,1000),graph=1)

header = ['z','vm','na','k','cl','x']
rows = np.array([np.linspace(-4,0.99,1000),np.array(vm),np.array(nai),np.array(ki),np.array(cli),np.array(xi)]).T

import csv
with open('data_fig1.csv','w') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(rows)

# %%
#dez = f5d()
pk, cli, ki, nai, w, xi, vm, ena, ek, ecl, ev = delta_gs3(Gk=np.linspace(1,1000,1000))

header = ['pk','vm','na','k','cl','x']
rows = np.array([pk,np.array(vm),np.array(nai),np.array(ki),np.array(cli),np.array(xi)]).T
plt.plot(pk,ena,label='ena')
plt.plot(pk,ev,label='vm')
plt.plot(pk,ecl,label='ecl')
plt.plot(pk,ek,label='ek')
plt.xlabel('gk*1.0e-4/F')
plt.legend()
plt.show()

import csv
with open('data_fig2_gk.csv','w') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(rows)
# Out:
# Initial values: na 0.014002 k 0.122873 cl 0.005163 x 0.154962 vm -0.06874556249996833
# w 1.9634954084936206e-12 radius 5e-05 z -0.85
# osi: 0.297
# z_aim: -100 with zflux of -1

# %%
epi = -1000*R/3*np.log(0.01/0.005)
plt.plot(pk,ena,label='ena')
plt.plot(pk,ev,label='vm')
plt.plot(pk,ecl,label='ecl')
plt.plot(pk,ek,label='ek')
plt.xlabel('pk*1.0e-4/F')
plt.legend()
plt.show()

plt.plot(pk,epi-ena,label='epi-ena')
plt.plot(pk,vm-ena,label='vm-ena')
plt.xlabel('pk*1.0e-4/F')
plt.legend()
plt.show()

# %%
#dez = f5d()
pk, cli, ki, nai, w, xi, vm, ena, ek, ecl, ev = delta_gs3(Gna=np.linspace(1,1000,1000))

header = ['pk','vm','na','k','cl','x']
rows = np.array([pk,np.array(vm),np.array(nai),np.array(ki),np.array(cli),np.array(xi)]).T
plt.plot(pk,ena,label='ena')
plt.plot(pk,ev,label='vm')
plt.plot(pk,ecl,label='ecl')
plt.plot(pk,ek,label='ek')
plt.xlabel('gna*1.0e-4/F')
plt.legend()
plt.show()

import csv
with open('data_fig3_gna.csv','w') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(rows)

# %%
for ecpin in [5e-11,2e-10,5e-10,2e-9,5e-9,2e-8,5e-8,2e-7]:
    dex=plm(tt=4*60*24,ecp=ecpin,xp=1000,tpend=4*60*22,phoscomb=0)
    fig, ax0, ax1, ax2, ax3=minithreefig([dex[11][1:-1],dex[14][1:-1],dex[13][1:-1],dex[16][1:-1],dex[12][1:-1],dex[10][1:-1],dex[20][1:-1],dex[-1]],colour='#d95f02',yl=[[-110,-60],[20,70],[1.9e-12,2.6e-12],[120,160]],title='TEST_EPi_2Na_H2PO42_chdir_separate_dna_phosphate_Na_transporter_dynamic_ATPase'+str(ecpin))
# Out:
# 0.01
# Initial values: na 0.014002 k 0.122873 cl 0.005163 x 0.154962 vm -0.06874556249996833
# w 1.9634954084936206e-12 radius 5e-05 z -0.85
# osi: 0.297
# z_aim: -100 with zflux of -1
#  93%|█████████▎| 537001/576000 [00:11<00:00, 42297.56it/s]
# Tp_end values: na 0.01401683424303167 k 0.12357106650355487 cl 0.005134455559279264 x 0.15427858451771786 vm -0.07275327607415401 cle 0.119 ose 0.297 osi 0.2970009438443852 deltx 6.967219514911976e-27
# 100%|██████████| 576000/576000 [00:12<00:00, 45099.16it/s]
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# Final values: na 0.014005953889213127 k 0.12358171885239 cl 0.0051371220419704966 x 0.15427521006010714 vm -0.0727210566028964 cle 0.119 ose 0.297 osi 0.29700000485923267 deltx 1.2116903504194741e-27
# ...

# %%
fig, ax0, ax1, ax2, ax3=minithreefig([dex[11][1:-1],dex[14][1:-1],dex[13][1:-1],dex[16][1:-1],dex[12][1:-1],dex[10][1:-1],dex[20][1:-1],dex[-1]],colour='#d95f02',yl=[[-110,-60],[20,70],[1.9e-12,2.6e-12],[120,160]],title='TEST_EPi_2Na_H2PO42_chdir_separate_dna_phosphate_Na_transporter_dynamic_ATPase')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
dex=plm(tt=4*60*60*24,ecp=2e-11,xp=1000,tpend=60*60*4*22,neww=4,phoscomb=1)
# Out:
# 0.01
# Initial values: na 0.014002 k 0.122873 cl 0.005163 x 0.154962 vm -0.06874556249996833
# w 1.9634954084936206e-12 radius 5e-05 z -0.85
# osi: 0.297
# z_aim: -100 with zflux of -1
#  27%|██▋       | 9228570/34560000 [02:58<07:54, 53410.29it/s]
# phosphate doubled
# Phos doub values: na 0.015176941082546526 k 0.13180030192608205 cl 0.004809918583885733 x 0.1452135084213586 vm -0.07451905790036166 cle 0.119 ose 0.297 osi 0.2970006721007963 deltx 3.3927329811745276e-26
#  52%|█████▏    | 18064279/34560000 [05:49<05:20, 51532.65it/s]
# phosphate doubled
# Phos doub values: na 0.016096411969389712 k 0.13978522357069234 cl 0.004535117940592616 x 0.1365839190658993 vm -0.0760910490027018 cle 0.119 ose 0.297 osi 0.29700067457799784 deltx -1.3510347407177137e-25
#  77%|███████▋  | 26644005/34560000 [08:36<02:28, 53305.57it/s]
# phosphate doubled
# ...

# %%
fig, ax0, ax1, ax2, ax3=minithreefig([dex[11][1:-1],dex[14][1:-1],dex[13][1:-1],dex[16][1:-1],dex[12][1:-1],dex[10][1:-1],dex[20][1:-1],dex[-1]],colour='#d95f02',yl=[[-110,-60],[20,70],[1.9e-12,2.6e-12],[120,160]],title='2Na_H2PO42_chdir_incorporated_dna_phosphate_Na_transporter_constant_ATPase')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
dex=plm(tt=24*60*60*4,ecp=2e-11,xp=1000,tpend=22*60*60*4,phoscomb=0)
fig, ax0, ax1, ax2, ax3=minithreefig([dex[11][1:-1],dex[14][1:-1],dex[13][1:-1],dex[16][1:-1],dex[12][1:-1],dex[10][1:-1],dex[20][1:-1],dex[-1]],colour='#d95f02',yl=[[-110,-60],[20,70],[1.9e-12,2.6e-12],[120,160]],title='2Na_H2PO42_chdir_phosphate_Na_transporter_dynamic_ATPase')
# Out:
# 0.01
# Initial values: na 0.014002 k 0.122873 cl 0.005163 x 0.154962 vm -0.06874556249996833
# w 1.9634954084936206e-12 radius 5e-05 z -0.85
# osi: 0.297
# z_aim: -100 with zflux of -1
#  27%|██▋       | 9240845/34560000 [03:08<09:11, 45891.76it/s]
# phosphate doubled
# Phos doub values: na 0.014043862268264382 k 0.1286172753483344 cl 0.004949982303535377 x 0.14938924290670205 vm -0.07363843943172181 cle 0.119 ose 0.297 osi 0.2970003639731331 deltx 6.522933053091502e-26
#  53%|█████▎    | 18158658/34560000 [06:11<06:03, 45105.57it/s]
# phosphate doubled
# Phos doub values: na 0.014072398839859609 k 0.13364768526442883 cl 0.004776197791134557 x 0.1445040617166257 vm -0.07452314681017072 cle 0.119 ose 0.297 osi 0.29700034467968617 deltx 1.130406122745501e-25
#  78%|███████▊  | 26894112/34560000 [09:10<02:34, 49638.09it/s]
# phosphate doubled
# ...

# %%
dex=plm(tt=24*60*60*4,ecp=2e-11,xp=1000,tpend=22*60*60*4,neww=4,phoscomb=0)
fig, ax0, ax1, ax2, ax3=minithreefig([dex[11][1:-1],dex[14][1:-1],dex[13][1:-1],dex[16][1:-1],dex[12][1:-1],dex[10][1:-1],dex[20][1:-1],dex[-1]],colour='#d95f02',yl=[[-110,-60],[20,70],[1.9e-12,2.6e-12],[120,160]],title='2Na_H2PO42_chdir_phosphate_Na_transporter_constant_ATPase')
# Out:
# 0.01
# Initial values: na 0.014002 k 0.122873 cl 0.005163 x 0.154962 vm -0.06874556249996833
# w 1.9634954084936206e-12 radius 5e-05 z -0.85
# osi: 0.297
# z_aim: -100 with zflux of -1
#  27%|██▋       | 9293763/34560000 [03:10<08:50, 47583.43it/s]
# phosphate doubled
# Phos doub values: na 0.014724119228364524 k 0.12793732689301388 cl 0.004957654503846889 x 0.1493812597520311 vm -0.07369716224331922 cle 0.119 ose 0.297 osi 0.2970003615157837 deltx 2.4233807008389483e-26
#  53%|█████▎    | 18318525/34560000 [06:17<05:33, 48653.52it/s]
# phosphate doubled
# Phos doub values: na 0.0152456848490784 k 0.13247445673405137 cl 0.0047880181577440615 x 0.1444921789695229 vm -0.0746265630830903 cle 0.119 ose 0.297 osi 0.29700033976276086 deltx 8.633293746738753e-27
#  79%|███████▊  | 27205309/34560000 [09:21<02:27, 49853.73it/s]
# phosphate doubled
# ...

# %%
flux = 0.01/(60*60*4)
Ar = 4e5
print(flux/Ar/(-(75e-3)-R*np.log(nao/15e-3)))
# Out:
# -1.280029377814764e-11

# %%
dex=plm(tt=4*60*60*24,ecp=2e-11,xp=1000,tpend=4*60*60*22,phoscomb=1,phoscharge=1)
fig, ax0, ax1, ax2, ax3=minithreefig([dex[11][1:-1],dex[14][1:-1],dex[13][1:-1],dex[16][1:-1],dex[12][1:-1],dex[10][1:-1],dex[20][1:-1],dex[-1]],colour='#d95f02',yl=[[-110,-60],[20,70],[1.9e-12,2.6e-12],[120,160]],title='2Na_H2PO4-_balance_chdir_incorporated_dna_phosphate_Na_transporter_dynamic_ATPase')

#dex=plm(tt=4*60*60*24,ecp=2e-11,xp=1000,tpend=60*60*4*22,neww=4,phoscomb=1,phoscharge=1)
#fig, ax0, ax1, ax2, ax3=minithreefig([dex[11][1:-1],dex[14][1:-1],dex[13][1:-1],dex[16][1:-1],dex[12][1:-1],dex[10][1:-1],dex[20][1:-1],dex[-1]],colour='#d95f02',yl=[[-110,-60],[20,70],[1.9e-12,2.6e-12],[120,160]],title='2Na_H2PO4-_chdir_incorporated_dna_phosphate_Na_transporter_constant_ATPase')

dex=plm(tt=24*60*60*4,ecp=2e-11,xp=1000,tpend=22*60*60*4,phoscomb=0,phoscharge=1)
fig, ax0, ax1, ax2, ax3=minithreefig([dex[11][1:-1],dex[14][1:-1],dex[13][1:-1],dex[16][1:-1],dex[12][1:-1],dex[10][1:-1],dex[20][1:-1],dex[-1]],colour='#d95f02',yl=[[-110,-60],[20,70],[1.9e-12,2.6e-12],[120,160]],title='2Na_H2PO4-__balance_chdir_phosphate_Na_transporter_dynamic_ATPase')

#dex=plm(tt=24*60*60*4,ecp=2e-11,xp=1000,tpend=22*60*60*4,neww=4,phoscomb=0,phoscharge=1)
#fig, ax0, ax1, ax2, ax3=minithreefig([dex[11][1:-1],dex[14][1:-1],dex[13][1:-1],dex[16][1:-1],dex[12][1:-1],dex[10][1:-1],dex[20][1:-1],dex[-1]],colour='#d95f02',yl=[[-110,-60],[20,70],[1.9e-12,2.6e-12],[120,160]],title='2Na_H2PO4-_chdir_phosphate_Na_transporter_constant_ATPase')
# Out:
# 0.01
# Initial values: na 0.014002 k 0.122873 cl 0.005163 x 0.154962 vm -0.06874556249996833
# w 1.9634954084936206e-12 radius 5e-05 z -0.85
# osi: 0.297
# z_aim: -100 with zflux of -1
#  14%|█▎        | 4675476/34560000 [02:08<15:15, 32625.41it/s]
# phosphate doubled
# Phos doub values: na 0.014041185943360833 k 0.1280484893423681 cl 0.004968126454788833 x 0.14994287136270026 vm -0.07356163578987913 cle 0.119 ose 0.297 osi 0.2970006752337381 deltx 1.0248880880631385e-26
#  26%|██▋       | 9152462/34560000 [04:12<11:18, 37441.11it/s]
# phosphate doubled
# Phos doub values: na 0.014068952480422805 k 0.13290817818820164 cl 0.00479850106341312 x 0.14522504711494594 vm -0.07442260098412265 cle 0.119 ose 0.297 osi 0.297000680961504 deltx -1.358102934428494e-26
#  39%|███▉      | 13527580/34560000 [06:24<12:32, 27952.26it/s]
# phosphate doubled
# ...
