# %% [markdown]
# # Figures 1-6
#
# Welcome to the jupyter notebook for the GitHub repository of the paper "Biophysical models reveal the relative importance of transporter proteins and impermeant anions in chloride homeostasis" (currently in review, view at https://www.biorxiv.org/content/early/2017/11/08/216150). This file is designed to allow you to run and tweak the code and see the associated Figures 1-6 in the paper.

# %% [markdown]
# ## Figure 1b-d

# %%
import figure_1
f1b = figure_1.f1b()
f1c = figure_1.f1c()
f1d = figure_1.f1d()
# Out:
# Figure 1B
# k_init: 0.1187157
# osi: 0.2886797
# z_aim: -100 with zflux of -1
# na 0.0140016477634 k 0.122873328047 cl 0.00516482453728 x 0.154960199813 vm -0.0725881088291 cle 0.119 ose 0.297 osi 0.297000000161 deltx 8.48183245294e-27
# w 1.9635182186e-12 radius 5.00002904265e-05 z -0.85
# ecl -83.843069517
# k_init: 0.1327157
# osi: 0.3166797
# z_aim: -100 with zflux of -1
# na 0.0140016477309 k 0.122873329886 cl 0.0051648555937 x 0.154960165398 vm -0.0725880797949 cle 0.119 ose 0.297 osi 0.296999998608 deltx -1.67617165141e-26
# w 1.96351865468e-12 radius 5.00002959788e-05 z -0.85
# ecl -83.8429076
# k_init: 0.1677157
# osi: 0.3866797
# z_aim: -100 with zflux of -1
# na 0.0140016463752 k 0.122873406667 cl 0.00516615239872 x 0.154958728329 vm -0.0725868675661 cle 0.119 ose 0.297 osi 0.296999933749 deltx -2.30726037559e-26
# w 1.96353686412e-12 radius 5.00005278266e-05 z -0.85
# ecl -83.8361474052
# k_init: 0.2077157
# osi: 0.4666797
# z_aim: -100 with zflux of -1
# ...

# %% [markdown]
# ## Figure 2a-d

# %%
import figure_2or3
f2 = figure_2or3.f2()
# Out:
# Figure 2A
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# Figure 2B
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# Figure 2C
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# Figure 2D
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1

# %% [markdown]
# ## Figure 3a-d

# %%
f3a = figure_2or3.f3a()
f3b_kcc, f3b_df, f3b_ecl, f3b_vm = figure_2or3.f3b()

# Fig 3C (meta-regression)
import regression
import matplotlib.pyplot as plt
df = True # set df to True to change y-variable to DF and include Vm change plot, or false to make it for Cl change only
a_df, b_df = regression.regplot(x=regression.a,y=regression.c)
if df == True:
    a_vm, b_vm = regression.regplot(x=regression.a,y=regression.v,an=[],bn=[])
plt.xlabel("Percentage change in KCC2 expression")
plt.ylabel("Change in mV")
plt.show()

f3d = figure_2or3.f3d()
# Out:
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014064750308406704 k 0.12267775556879207 cl 0.003532343988517994 x 0.1567251498782517 vm -0.07454005208389158 cle 0.119 ose 0.297 osi 0.29699999974388586 deltx -2.524354896707238e-28
# w 1.941406186099366e-12 radius 4.9717955796021876e-05 z -0.85
# ecl -93.9961497225862
# Figure 3A
# 3.80729610662e-07
# -83.85251199079462
# 5.163
# 3.5323439885552235
# -93.9961497225862
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
#
# Figure 3B
# LinregressResult(slope=17.26940869621163, intercept=-4.996114556266269, rvalue=0.8923873361091037, pvalue=2.807755435363947e-77, stderr=0.591469738854704)
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     852.5
# ...

# %% [markdown]
# ## Figure 4a-d

# %%
import fig4
f4a = fig4.f4a()
f4b = fig4.f4b()
f4c = fig4.f4c()
f4d = fig4.f4d()
# Out:
# Figure 4D
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# na 0.014001766852116068 k 0.1228928510111027 cl 0.0054070337632837594 x 0.1546983504559651 vm -0.07259181699058696 cle 0.124600000003 ose 0.297000000003 osi 0.2970000020831344 deltx 2.5950368338150404e-26
# w 1.9668417574861214e-12 radius 5.004258890053288e-05 z -0.85
# ecl -83.84722906345017
# 11.25541179271302
# 11.2554863279221

# %% [markdown]
# ## Figure 5a-d

# %%
import fig5
f5a = fig5.f5a()
f5b = fig5.f5b()
f5c = fig5.f5c()
f5d = fig5.f5d()
# Out:
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1
# na 0.0140507271655 k 0.131219393389 cl 0.0048576087334 x 0.146872284359 vm -0.0741071046538 cle 0.119 ose 0.297 osi 0.297000013651 deltx -6.22404943332e-25
# w 2.07164460483e-12 radius 5.13585419721e-05 z -0.956058486098
# ecl -85.4819869332
# Figure 5A
# 11.3748802589
# Figure 5B
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# k_init: 0.122873
# osi: 0.272344363636
# z_aim: -100 with zflux of -1
# na 0.0141371209629 k 0.147463884743 cl 0.00435700677373 x 0.131041987522 vm -0.0768038026266 cle 0.119 ose 0.297 osi 0.297000000002 deltx -2.26081224549e-25
# w 1.952473032e-12 radius 4.98594612323e-05 z -1.2
# ecl -88.3886131646
# k_init: 0.122873
# osi: 0.275374744186
# z_aim: -100 with zflux of -1
# na 0.0141217825635 k 0.144425797323 cl 0.00444239352703 x 0.13401002659 vm -0.0763227901732 cle 0.119 ose 0.297 osi 0.297000000003 deltx 1.97202604531e-25
# w 1.95363057269e-12 radius 4.98742388509e-05 z -1.15
# ...

# %% [markdown]
# ## Figure 6a-d,f

# %%
import fig6
f6a = fig5.f5a(new=1)
f6b = fig6.f6b()
f6c = fig4.f4c(new=1)
f6d = fig6.f6d()
f6f = figure_2or3.f3d(new=1)
# Out:
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1
# na 0.0140507271655 k 0.131219393389 cl 0.0048576087334 x 0.146872284359 vm -0.0741071046538 cle 0.119 ose 0.297 osi 0.297000013651 deltx -6.22404943332e-25
# w 2.07164460483e-12 radius 5.13585419721e-05 z -0.956058486098
# ecl -85.4819869332
# Figure 6A
# 11.3748802589
# k_init: 0.122873
# osi: 0.297
# z_aim: -1 with zflux of -1
# na 0.0151770461572 k 0.130094785417 cl 0.00486649239562 x 0.146861683183 vm -0.0742407680426 cle 0.119 ose 0.297 osi 0.297000007155 deltx -5.91102942613e-25
# w 2.07179414601e-12 radius 5.13603955908e-05 z -0.956078731511
# ecl -85.4331511237
# 11.192303791
# Figure 6B
# k_init: 0.122873
# osi: 0.297
# z_aim: -100 with zflux of -1
# k_init: 0.122873
# osi: 0.272344363636
# z_aim: -100 with zflux of -1
# na 0.014137121669 k 0.147463923065 cl 0.00435668968139 x 0.13104228432 vm -0.0768041622416 cle 0.119 ose 0.297 osi 0.297000018741 deltx 5.95747755623e-27
# ...
