# %%
import plm_singlecomp_withkcc2

# %%
para=plm_singlecomp_withkcc2.zplm()
print para[0]
print para[2]
print para[3]
print para[5]
print para[6]
print para[7]
print para[8]
print para[9]
# Out:
# [-2500.0249680278803]
# [-90.606568353426681]
# [-83.571351165336566]
# [-76.53613397724645]
# [0.033017409154452948]
# [0.10386509929089591]
# [0.0052176041593034695]
# [0.15489988739534769]

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(para[0],para[8],color=plm_singlecomp_withkcc2.clcolor)
plt.plot(para[0],para[7],color=plm_singlecomp_withkcc2.kcolor)
plt.plot(para[0],para[6],color=plm_singlecomp_withkcc2.nacolor)
plt.plot(para[0],para[9],color=plm_singlecomp_withkcc2.xcolor)
plt.ylabel('concentration (M)')
plt.xlabel('pump rate')
plt.savefig('pump_M.eps')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c821f8c8f6c9> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 plt.figure()
# ----> 3 plt.plot(para[0],para[8],color=plm_singlecomp_withkcc2.clcolor)
#       4 plt.plot(para[0],para[7],color=plm_singlecomp_withkcc2.kcolor)
#       5 plt.plot(para[0],para[6],color=plm_singlecomp_withkcc2.nacolor)
#
# NameError: name 'para' is not defined

# %%
import figure_1
figure_1.f1d()
# Out:
# k_init: 0.1039
# ose: 0.297
# z_aim: -100 with zflux of -1
# na 0.142619220619 k 0.0034956052921 cl 0.119082661565 x 0.031802512524 vm 7.57527584876e-05 cle 0.119 ose 0.297 deltx -1.148581478e-27
# w 4.97305450455e-13 radius 1.10348134881e-05
# 25
# k_init: 0.1039
# ose: 0.297
# z_aim: -100 with zflux of -1
# na 0.141424016879 k 0.00385393793558 cl 0.108767964265 x 0.0429540809206 vm -0.00222420801289 cle 0.119 ose 0.297 deltx 8.23570785051e-28
# w 3.68196978666e-13 radius 9.4949678321e-06
# 25
# k_init: 0.1039
# ose: 0.297
# z_aim: -100 with zflux of -1
# na 0.138803847336 k 0.00481118766214 cl 0.0882789833423 x 0.0651059816596 vm -0.0074579255967 cle 0.119 ose 0.297 deltx -5.05502068066e-27
# w 2.42920272657e-13 radius 7.71232402073e-06
# 25
# k_init: 0.1039
# ose: 0.297
# z_aim: -100 with zflux of -1
# na 0.13202828838 k 0.00857100011078 cl 0.0511543874741 x 0.105246324035 vm -0.0210800330303 cle 0.119 ose 0.297 deltx -6.24777836935e-28
# ...

# %%
import fig4
fig4.f4b()
# Out:
# k_init: -0.00655
# ose: 0.05665
# z_aim: -100 with zflux of -1
# plm_singlecomp_withkcc2.py:191: RuntimeWarning: invalid value encountered in log
#   K.append(1000*R*np.log(ke/k))
# plm_singlecomp_withkcc2.py:228: RuntimeWarning: invalid value encountered in log
#   dk=-dt*Ar*(gk*(V-R*np.log(ke/k))-ck*jp*sw-jkcc2)
# na nan k nan cl nan x nan vm nan cle 0.119 ose 0.297 deltx nan
# w nan radius nan
# nan
# nan
# nan
# k_init: 0.02745
# ose: 0.13065
# z_aim: -100 with zflux of -1
# na 0.0330157730093 k 0.103813848436 cl 0.00522005470411 x 0.15495032385 vm -0.0765242264356 cle 0.119 ose 0.297 deltx 2.77679038638e-27
# w 4.28305944499e-14 radius 3.23839961003e-06
# -76.5242264356
# -90.5933780024
# -83.5588022189
# k_init: 0.06145
# ose: 0.20465
# z_aim: -100 with zflux of -1
# na 0.0330159975853 k 0.103824871216 cl 0.00521952854236 x 0.154939602656 vm -0.0765267767998 cle 0.119 ose 0.297 deltx 1.82069096925e-27
# w 6.91926708638e-14 radius 4.11607647266e-06
# -76.5267767998
# ...
